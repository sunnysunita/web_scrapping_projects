# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnysunita/web_scrapping_projects/blob/master/rotten_tomatto_data_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
base_url = "https://editorial.rottentomatoes.com/guide/140-essential-action-movies-to-watch-now/2/"

# %%
response = requests.get(base_url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "lxml")
file = open("rotten.html","wb")
file.write(soup.prettify("utf-8"))
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="From John Wick and Die Hard to Mad Max and Atomic Blonde, these best action movies ever will thrill you and get the adrenaline pumping!" property="og.description"/>
# <meta content="From John Wick and Die Hard to Mad Max and Atomic Blonde, these best action movies ever will thrill you and get the adrenaline pumping!" name="description"/>
# <meta content="140 Essential Action Movies To Watch Now" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2019/06/06180025/RT_140_ESSENTIAL_ACTION_600x314.jpg" property="og:image"/>
# <meta content="https://editorial.rottentomatoes.com/guide/140-essential-action-movies-to-watch-now/" property="og:url"/>
# ...

# %%
outer_block = soup.find_all("div", attrs = {"class":"col-sm-18 col-full-xs countdown-item-content"})
outer_block
# Out:
# [<div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/1018009-running_scared/">Running Scared</a> <span class="subtle start-year">(1986)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">60%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#140</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
# ...

# %%
outer_block[0]
# Out:
# <div class="col-sm-18 col-full-xs countdown-item-content">
# <div class="row countdown-item-title-bar">
# <div class="col-sm-20 col-full-xs" style="height: 100%;">
# <div class="article_movie_title" style="float: left;">
# <div><h2><a href="https://www.rottentomatoes.com/m/1018009-running_scared/">Running Scared</a> <span class="subtle start-year">(1986)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">60%</span></h2></div>
# </div>
# </div>
# <div class="col-sm-4 col-full-xs" style="height: 100%;">
# <div class="countdown-index">#140</div>
# </div>
# </div>
# <div class="row countdown-item-details">
# <div class="col-sm-24">
# ...

# %%
outer_block[0].find("div", attrs = {"class":"info critics-consensus"}).text[19:]
# Out:
# 'Running Scared struggles to strike a consistent balance between violent action and humor, but the chemistry between its well-matched leads keeps things entertaining.'

# %%
(outer_block[0].find("h2")).find("a").string
# Out:
# 'Running Scared'

# %%
(outer_block[0].find("h2")).find("span", attrs={"class":"subtle start-year"}).string
# Out:
# '(1986)'

# %%
(outer_block[0].find("h2")).find("span", attrs={"class":"tMeterScore"}).string
# Out:
# '60%'

# %%
# temp = e.find("h2")

# temp.find("div", attrs = {"class":"info critics-consensus"}).text[19:]
outer_block[0].find("div", attrs = {"class":"info critics-consensus"}).text[19:]
# Out:
# 'Running Scared struggles to strike a consistent balance between violent action and humor, but the chemistry between its well-matched leads keeps things entertaining.'

# %%
list_movies = []
for e in outer_block:
  movie_dic = {}
  temp = e.find("h2")
  movie_dic["Movie_Name"] = temp.find("a").string
  movie_dic["Year_Release"] = temp.find("span", attrs={"class":"subtle start-year"}).string
  movie_dic["Rating"] = temp.find("span", attrs={"class":"tMeterScore"}).string
  movie_dic["Critics_Consensus"] = e.find("div", attrs = {"class":"info critics-consensus"}).text[19:]
  movie_dic["Synopsis"] = e.find("div", attrs = {"class":"info synopsis"}).text[9:]
  movie_dic["Starring"] = e.find("div", attrs = {"class":"info cast"}).text.strip()[9:]
  movie_dic["Directed_By"] = e.find("div", attrs = {"class":"info director"}).text.strip()[12:]
  list_movies.append(movie_dic)

# %%
len(list_movies)
# Out:
# 140

# %%
print(list_movies)
# Out:
# [{'Movie_Name': 'Running Scared', 'Year_Release': '(1986)', 'Rating': '60%', 'Critics_Consensus': 'Running Scared struggles to strike a consistent balance between violent action and humor, but the chemistry between its well-matched leads keeps things entertaining.', 'Synopsis': ' Distinguished by a sharp, witty dialogue between its two cop protagonists, Ray and Danny (Gregory Hines and Billy Crystal), this... [More]', 'Starring': ' Gregory Hines, Billy Crystal, Jimmy Smits, Steven Bauer', 'Directed_By': ' Peter Hyams'}, {'Movie_Name': 'Equilibrium', 'Year_Release': '(2002)', 'Rating': '40%', 'Critics_Consensus': 'Equilibrium is a reheated mishmash of other sci-fi movies.', 'Synopsis': ' In the nation of Libria, there is always peace among men. The rules of the Librian system are simple. If... [More]', 'Starring': ' Christian Bale, Emily Watson, Taye Diggs, Angus Macfadyen', 'Directed_By': ' Kurt Wimmer'}, {'Movie_Name': 'Hero', 'Year_Release': '(2004)', 'Rating': '95%', 'Critics_Cons
# ...

# %%
import pandas as pd

# %%
movie = pd.DataFrame(list_movies)

# %%
movie.head()
# Out:
#        Movie_Name  ...        Directed_By
# 0  Running Scared  ...        Peter Hyams
# 1     Equilibrium  ...        Kurt Wimmer
# 2            Hero  ...        Zhang Yimou
# 3      Road House  ...   Rowdy Herrington
# 4     Unstoppable  ...         Tony Scott
#
# [5 rows x 7 columns]

# %%
movie.to_excel("movies_from_rotten_tomatoes.xlsx")
